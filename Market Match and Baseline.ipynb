# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial import distance

# %%
import pathlib
pathlib.Path().resolve()
# Out:
# WindowsPath('C:/Users/anoda/Documents/Wix')

# %%
#df = pd.read_csv('Cerebelly Local Test Control Market Selection Input Data 20231027.csv')
df = pd.read_excel('C:/Users/anoda/Documents/Wix/Wix - Control Market Input.xlsx', sheet_name='Sheet1')

# %%
df.columns
# Out:
# Index(['Market', 'BDI', 'Target Population (Adults 25-54)',
#        'SMB Per T Pop Index.', 'Selected Market \n(Y/blank)'],
#       dtype='object')

# %%
columns_check = df.columns.difference(['Selected Market \n(Y/blank)'])

df1 = df.dropna(subset=columns_check)

# %%
columns_check
# Out:
# Index(['BDI', 'Market', 'SMB Per T Pop Index.',
#        'Target Population (Adults 25-54)'],
#       dtype='object')

# %%
numeric_cols = df1.select_dtypes(include=['number'])
df1[numeric_cols.columns] = (numeric_cols - numeric_cols.mean()) / numeric_cols.std()

# %%
df1.columns
# Out:
# Index(['Market', 'BDI', 'Target Population (Adults 25-54)',
#        'SMB Per T Pop Index.', 'Selected Market \n(Y/blank)'],
#       dtype='object')

# %%
cos_sim = cosine_similarity(df1.iloc[:,1:3])

# %%
test_df = df1[df1['Selected Market \n(Y/blank)']=="Y"]

# %%
cos_sim.shape
# Out:
# (176, 176)

# %%
cos_sim = pd.DataFrame(cos_sim).set_index(df1['Market'])

# %%
cos_sim.columns = df1['Market']

# %%
cos_out = (cos_sim + 1) * 0.5

# %%
cos_out.to_csv('cos_sim_results.csv')

# %%
def top_5_similar(df):
    top_5 = {}
    for index, row in df.iterrows():
        top_similar = row.sort_values(ascending=False).drop(index).head(5)
        top_5[index] = top_similar.index.tolist()
    return top_5

top_5_similar_dmas = top_5_similar(cos_out)

# %%
df_top_5 = pd.DataFrame.from_dict(top_5_similar_dmas, orient='index').reset_index()
df_top_5.columns = ['DMA', 'Most Similar 1', 'Most Similar 2', 'Most Similar 3', 'Most Similar 4', 'Most Similar 5']

# Export the DataFrame to CSV
df_top_5.to_csv('top_5_similar_dmas.csv', index=False)

# %%
distances_df = pd.DataFrame()
for idx1, row1 in test_df[numeric_cols.columns].iterrows():
    row_distances = []
    for idx2, row2 in df1[numeric_cols.columns].iterrows():
        euclidean_dist = distance.euclidean(row1, row2)
        row_distances.append(euclidean_dist)
    distances_df[f'Row {idx1 + 1}'] = row_distances

# %%
distances_df.set_index(df1['Market'], inplace=True)
distances_df.columns = test_df['Market']

# %%
top_5_similar_dmas
# Out:
# {'Seattle-Tacoma WA': ['San Antonio TX',
#   'San Francisco-Oakland-San Jose CA',
#   'Phoenix AZ',
#   'Houston TX',
#   'Dallas-Ft. Worth TX'],
#  'Boise ID': ['Baton Rouge LA',
#   'Wilmington NC',
#   'Jackson TN',
#   'Amarillo TX',
#   'Columbus GA'],
#  'Nashville TN': ['Minneapolis-St. Paul MN',
#   'Milwaukee WI',
#   'Columbus OH',
#   'Portland OR',
#   'Boston MA-Manchester NH'],
#  'Oklahoma City OK': ['New Orleans LA',
#   'Grand Rapids-Kalamazoo-Battle Creek MI',
#   'West Palm Beach-Ft. Pierce FL',
#   'Harrisburg-Lancaster-Lebanon-York PA',
#   'Greensboro-High Point-Winston Salem NC'],
#  'Louisville KY': ['Fresno-Visalia CA',
#   'Albuquerque-Santa Fe NM',
#   'Memphis TN',
#   'Greensboro-High Point-Winston Salem NC',
#   'Harrisburg-Lancaster-Lebanon-York PA'],
#  'Monterey-Salinas CA': ['Providence-New Bedford,MA',
#   'Austin TX',
#   'Zanesville OH',
#   'Las Vegas NV',
#   'Yakima-Pasco-Richland-Kennewick WA'],
#  'Zanesville OH': ['Yakima-Pasco-Richland-Kennewick WA',
#   'Bend OR',
#   'Lafayette IN',
#   'Gainesville FL',
#   'Roanoke-Lynchburg VA'],
#  'Austin TX': ['Providence-New Bedford,MA',
#   'Monterey-Salinas CA',
#   'Las Vegas NV',
#   'Charlotte NC',
#   'Zanesville OH'],
#  'Charlotte NC': ['Las Vegas NV',
#   'Salt Lake City UT',
#   'Miami-Ft. Lauderdale FL',
#   'Atlanta GA',
#   'Washington DC (Hagerstown MD)'],
#  'Providence-New Bedford,MA': ['Monterey-Salinas CA',
#   'Austin TX',
#   'Zanesville OH',
#   'Las Vegas NV',
#   'Yakima-Pasco-Richland-Kennewick WA'],
#  'Atlanta GA': ['Washington DC (Hagerstown MD)',
#   'Denver CO',
#   'Miami-Ft. Lauderdale FL',
#   'Dallas-Ft. Worth TX',
#   'Salt Lake City UT'],
#  'Washington DC (Hagerstown MD)': ['Denver CO',
#   'Atlanta GA',
#   'Dallas-Ft. Worth TX',
#   'Miami-Ft. Lauderdale FL',
#   'San Antonio TX'],
#  'Bend OR': ['Yakima-Pasco-Richland-Kennewick WA',
#   'Lafayette IN',
#   'Gainesville FL',
#   'Roanoke-Lynchburg VA',
#   'Ft. Myers-Naples FL'],
#  'Dallas-Ft. Worth TX': ['Denver CO',
#   'San Antonio TX',
#   'Washington DC (Hagerstown MD)',
#   'Atlanta GA',
#   'Seattle-Tacoma WA'],
#  'Yakima-Pasco-Richland-Kennewick WA': ['Bend OR',
#   'Lafayette IN',
#   'Gainesville FL',
#   'Roanoke-Lynchburg VA',
#   'Ft. Myers-Naples FL'],
#  'Miami-Ft. Lauderdale FL': ['Salt Lake City UT',
#   'Atlanta GA',
#   'Washington DC (Hagerstown MD)',
#   'Denver CO',
#   'Dallas-Ft. Worth TX'],
#  'Las Vegas NV': ['Charlotte NC',
#   'Salt Lake City UT',
#   'Miami-Ft. Lauderdale FL',
#   'Atlanta GA',
#   'Washington DC (Hagerstown MD)'],
#  'Lafayette IN': ['Gainesville FL',
#   'Roanoke-Lynchburg VA',
#   'Ft. Myers-Naples FL',
#   'Biloxi-Gulfport MS',
#   'Bend OR'],
#  'Denver CO': ['Washington DC (Hagerstown MD)',
#   'Atlanta GA',
#   'Dallas-Ft. Worth TX',
#   'Miami-Ft. Lauderdale FL',
#   'San Antonio TX'],
#  'Gainesville FL': ['Lafayette IN',
#   'Roanoke-Lynchburg VA',
#   'Ft. Myers-Naples FL',
#   'Biloxi-Gulfport MS',
#   'Savannah GA'],
#  'Salt Lake City UT': ['Miami-Ft. Lauderdale FL',
#   'Atlanta GA',
#   'Washington DC (Hagerstown MD)',
#   'Denver CO',
#   'Dallas-Ft. Worth TX'],
#  'Biloxi-Gulfport MS': ['Savannah GA',
#   'Ft. Myers-Naples FL',
#   'Tallahassee FL-Thomasville GA',
#   'Amarillo TX',
#   'Jackson TN'],
#  'Roanoke-Lynchburg VA': ['Gainesville FL',
#   'Lafayette IN',
#   'Ft. Myers-Naples FL',
#   'Biloxi-Gulfport MS',
#   'Savannah GA'],
#  'San Francisco-Oakland-San Jose CA': ['Phoenix AZ',
#   'Houston TX',
#   'New York, NY',
#   'Los Angeles CA',
#   'Chicago IL'],
#  'Houston TX': ['Phoenix AZ',
#   'San Francisco-Oakland-San Jose CA',
#   'New York, NY',
#   'Los Angeles CA',
#   'Chicago IL'],
#  'Ft. Myers-Naples FL': ['Biloxi-Gulfport MS',
#   'Savannah GA',
#   'Tallahassee FL-Thomasville GA',
#   'Amarillo TX',
#   'Jackson TN'],
#  'San Antonio TX': ['Dallas-Ft. Worth TX',
#   'Seattle-Tacoma WA',
#   'Denver CO',
#   'Washington DC (Hagerstown MD)',
#   'Atlanta GA'],
#  'Savannah GA': ['Biloxi-Gulfport MS',
#   'Tallahassee FL-Thomasville GA',
#   'Ft. Myers-Naples FL',
#   'Amarillo TX',
#   'Jackson TN'],
#  'Phoenix AZ': ['San Francisco-Oakland-San Jose CA',
#   'Houston TX',
#   'New York, NY',
#   'Los Angeles CA',
#   'Chicago IL'],
#  'Tallahassee FL-Thomasville GA': ['Amarillo TX',
#   'Jackson TN',
#   'Savannah GA',
#   'Biloxi-Gulfport MS',
#   'Boise ID'],
#  'Jackson TN': ['Amarillo TX',
#   'Tallahassee FL-Thomasville GA',
#   'Savannah GA',
#   'Boise ID',
#   'Baton Rouge LA'],
#  'Amarillo TX': ['Jackson TN',
#   'Tallahassee FL-Thomasville GA',
#   'Savannah GA',
#   'Boise ID',
#   'Baton Rouge LA'],
#  'Jacksonville FL': ['Raleigh-Durham (Fayetteville) NC',
#   'Detroit MI',
#   'Sacramento-Stockton-Modesto CA',
#   'Philadelphia PA',
#   'Boston MA-Manchester NH'],
#  'Kansas City MO': ['Chicago IL',
#   'Los Angeles CA',
#   'New York, NY',
#   'Philadelphia PA',
#   'Houston TX'],
#  'Baton Rouge LA': ['Boise ID',
#   'Wilmington NC',
#   'Columbus GA',
#   'Jackson TN',
#   'Amarillo TX'],
#  'New York, NY': ['Los Angeles CA',
#   'Chicago IL',
#   'Kansas City MO',
#   'Houston TX',
#   'Phoenix AZ'],
#  'Los Angeles CA': ['New York, NY',
#   'Chicago IL',
#   'Kansas City MO',
#   'Houston TX',
#   'Phoenix AZ'],
#  'Milwaukee WI': ['Columbus OH',
#   'Nashville TN',
#   'Minneapolis-St. Paul MN',
#   'Boston MA-Manchester NH',
#   'Sacramento-Stockton-Modesto CA'],
#  'Raleigh-Durham (Fayetteville) NC': ['Jacksonville FL',
#   'Philadelphia PA',
#   'Detroit MI',
#   'Sacramento-Stockton-Modesto CA',
#   'Boston MA-Manchester NH'],
#  'Columbus GA': ['Wilmington NC',
#   'Idaho Falls-Pocatello ID',
#   'Baton Rouge LA',
#   'Boise ID',
#   'Waco-Temple-Bryan TX'],
#  'Wilmington NC': ['Columbus GA',
#   'Idaho Falls-Pocatello ID',
#   'Baton Rouge LA',
#   'Boise ID',
#   'Waco-Temple-Bryan TX'],
#  'Columbus OH': ['Milwaukee WI',
#   'Nashville TN',
#   'Minneapolis-St. Paul MN',
#   'Boston MA-Manchester NH',
#   'Sacramento-Stockton-Modesto CA'],
#  'Chicago IL': ['Los Angeles CA',
#   'Kansas City MO',
#   'New York, NY',
#   'Philadelphia PA',
#   'Houston TX'],
#  'New Orleans LA': ['Oklahoma City OK',
#   'Grand Rapids-Kalamazoo-Battle Creek MI',
#   'West Palm Beach-Ft. Pierce FL',
#   'Harrisburg-Lancaster-Lebanon-York PA',
#   'Greensboro-High Point-Winston Salem NC'],
#  'Waco-Temple-Bryan TX': ['Charleston SC',
#   'Grand Junction-Montrose CO',
#   'Missoula MT',
#   'Idaho Falls-Pocatello ID',
#   'Cheyenne WY-Scottsbluff NE'],
#  'Idaho Falls-Pocatello ID': ['Columbus GA',
#   'Wilmington NC',
#   'Baton Rouge LA',
#   'Boise ID',
#   'Waco-Temple-Bryan TX'],
#  'West Palm Beach-Ft. Pierce FL': ['Hartford & New Haven CT',
#   'Indianapolis IN',
#   'New Orleans LA',
#   'Cincinnati OH',
#   'Oklahoma City OK'],
#  'Charleston SC': ['Waco-Temple-Bryan TX',
#   'Grand Junction-Montrose CO',
#   'Missoula MT',
#   'Cheyenne WY-Scottsbluff NE',
#   'Idaho Falls-Pocatello ID'],
#  'Norfolk-Portsmouth-Newport News VA': ['Cincinnati OH',
#   'Indianapolis IN',
#   'Pittsburgh PA',
#   'Hartford & New Haven CT',
#   'San Diego CA'],
#  'Sacramento-Stockton-Modesto CA': ['Detroit MI',
#   'Boston MA-Manchester NH',
#   'Jacksonville FL',
#   'Raleigh-Durham (Fayetteville) NC',
#   'Columbus OH'],
#  'Philadelphia PA': ['Kansas City MO',
#   'Raleigh-Durham (Fayetteville) NC',
#   'Jacksonville FL',
#   'Chicago IL',
#   'Los Angeles CA'],
#  'Richmond-Petersburg VA': ['Lexington KY',
#   'Tulsa OK',
#   'Knoxville TN',
#   'Honolulu HI',
#   'Charleston-Huntington WV'],
#  'Portland OR': ['Minneapolis-St. Paul MN',
#   'Nashville TN',
#   'Baltimore MD',
#   'Milwaukee WI',
#   'Cleveland-Akron (Canton) OH'],
#  'Detroit MI': ['Sacramento-Stockton-Modesto CA',
#   'Boston MA-Manchester NH',
#   'Jacksonville FL',
#   'Raleigh-Durham (Fayetteville) NC',
#   'Columbus OH'],
#  'Baltimore MD': ['Cleveland-Akron (Canton) OH',
#   'San Diego CA',
#   'Portland OR',
#   'Minneapolis-St. Paul MN',
#   'Nashville TN'],
#  'Greensboro-High Point-Winston Salem NC': ['Memphis TN',
#   'Harrisburg-Lancaster-Lebanon-York PA',
#   'Albuquerque-Santa Fe NM',
#   'Grand Rapids-Kalamazoo-Battle Creek MI',
#   'Fresno-Visalia CA'],
#  'Omaha NE': ['Chico-Redding CA',
#   'Yuma AZ-El Centro CA',
#   'Casper-Riverton WY',
#   'Utica NY',
#   'Sherman-Ada, OK'],
#  'Grand Junction-Montrose CO': ['Charleston SC',
#   'Waco-Temple-Bryan TX',
#   'Missoula MT',
#   'Cheyenne WY-Scottsbluff NE',
#   'Bowling Green KY'],
#  'Syracuse NY': ['Florence-Myrtle Beach SC',
#   'Medford-Klamath Falls OR',
#   'Anchorage AK',
#   'Greenville-New Bern-Washington NC',
#   'Lansing MI'],
#  'San Diego CA': ['Cleveland-Akron (Canton) OH',
#   'Baltimore MD',
#   'Portland OR',
#   'Minneapolis-St. Paul MN',
#   'Nashville TN'],
#  'Missoula MT': ['Cheyenne WY-Scottsbluff NE',
#   'Bowling Green KY',
#   'Grand Junction-Montrose CO',
#   'Lubbock TX',
#   'Palm Springs CA'],
#  'Tucson (Sierra Vista) AZ': ['Watertown NY',
#   'Erie PA',
#   'Columbia SC',
#   'Alexandria LA',
#   'Reno NV'],
#  'Columbia SC': ['Erie PA',
#   'Reno NV',
#   'Tucson (Sierra Vista) AZ',
#   'Watertown NY',
#   'Lima OH'],
#  'Rochester NY': ['Laredo TX',
#   'Lincoln & Hastings-Kearney NE',
#   'Topeka KS',
#   'Ottumwa IA-Kirksville MO',
#   'Fairbanks AK'],
#  'Lubbock TX': ['Palm Springs CA',
#   'Bowling Green KY',
#   'Eugene OR',
#   'Cheyenne WY-Scottsbluff NE',
#   'San Angelo TX'],
#  'Eugene OR': ['San Angelo TX',
#   'Palm Springs CA',
#   'Lubbock TX',
#   'Lafayette LA',
#   'Bowling Green KY'],
#  'Minneapolis-St. Paul MN': ['Nashville TN',
#   'Milwaukee WI',
#   'Columbus OH',
#   'Portland OR',
#   'Boston MA-Manchester NH'],
#  'Cincinnati OH': ['Norfolk-Portsmouth-Newport News VA',
#   'Indianapolis IN',
#   'Hartford & New Haven CT',
#   'Pittsburgh PA',
#   'San Diego CA'],
#  'Palm Springs CA': ['Lubbock TX',
#   'Bowling Green KY',
#   'Eugene OR',
#   'San Angelo TX',
#   'Cheyenne WY-Scottsbluff NE'],
#  'Cheyenne WY-Scottsbluff NE': ['Missoula MT',
#   'Bowling Green KY',
#   'Lubbock TX',
#   'Palm Springs CA',
#   'Grand Junction-Montrose CO'],
#  'Bowling Green KY': ['Cheyenne WY-Scottsbluff NE',
#   'Lubbock TX',
#   'Palm Springs CA',
#   'Missoula MT',
#   'Eugene OR'],
#  'Boston MA-Manchester NH': ['Sacramento-Stockton-Modesto CA',
#   'Detroit MI',
#   'Columbus OH',
#   'Jacksonville FL',
#   'Milwaukee WI'],
#  'Lafayette LA': ['Juneau AK',
#   'San Angelo TX',
#   'Hattiesburg-Laurel MS',
#   'Eugene OR',
#   'Albany GA'],
#  'Cleveland-Akron (Canton) OH': ['San Diego CA',
#   'Baltimore MD',
#   'Portland OR',
#   'Minneapolis-St. Paul MN',
#   'Nashville TN'],
#  'Honolulu HI': ['Knoxville TN',
#   'Wichita-Hutchinson KS',
#   'Shreveport LA',
#   'Richmond-Petersburg VA',
#   'Flint-Saginaw-Bay City MI'],
#  'Pittsburgh PA': ['Norfolk-Portsmouth-Newport News VA',
#   'Cincinnati OH',
#   'San Diego CA',
#   'Cleveland-Akron (Canton) OH',
#   'Baltimore MD'],
#  'Greenville-New Bern-Washington NC': ['Florence-Myrtle Beach SC',
#   'Syracuse NY',
#   'Medford-Klamath Falls OR',
#   'Odessa-Midland TX',
#   'Anchorage AK'],
#  'Memphis TN': ['Greensboro-High Point-Winston Salem NC',
#   'Harrisburg-Lancaster-Lebanon-York PA',
#   'Albuquerque-Santa Fe NM',
#   'Fresno-Visalia CA',
#   'Grand Rapids-Kalamazoo-Battle Creek MI'],
#  'Florence-Myrtle Beach SC': ['Syracuse NY',
#   'Medford-Klamath Falls OR',
#   'Greenville-New Bern-Washington NC',
#   'Anchorage AK',
#   'Lansing MI'],
#  'Dayton OH': ['Tri-Cities TN-VA',
#   'Springfield MO',
#   'Burlington VT-Plattsburgh NY',
#   'Davenport IA-Rock Island-Moline IL',
#   'Evansville IN'],
#  'Jackson MS': ['Augusta GA',
#   'Presque Isle ME',
#   'Beaumont-Port Arthur TX',
#   'Bangor ME',
#   'Alexandria LA'],
#  'Spokane WA': ['Sioux City IA',
#   'Huntsville-Decatur (Florence) AL',
#   'Youngstown OH',
#   'Monroe LA-El Dorado AR',
#   'Bluefield-Beckley-Oak Hill WV'],
#  'Lansing MI': ['Anchorage AK',
#   'Medford-Klamath Falls OR',
#   'Syracuse NY',
#   'Florence-Myrtle Beach SC',
#   'Marquette MI'],
#  'Buffalo NY': ['Wilkes Barre-Scranton PA',
#   'Little Rock-Pine Bluff AR',
#   'Albany-Schenectady-Troy NY',
#   'Charleston-Huntington WV',
#   'Tulsa OK'],
#  'Des Moines-Ames IA': ['Evansville IN',
#   'Springfield-Holyoke MA',
#   'El Paso TX',
#   'Bluefield-Beckley-Oak Hill WV',
#   'Monroe LA-El Dorado AR'],
#  'Grand Rapids-Kalamazoo-Battle Creek MI': ['Oklahoma City OK',
#   'New Orleans LA',
#   'Harrisburg-Lancaster-Lebanon-York PA',
#   'Greensboro-High Point-Winston Salem NC',
#   'Memphis TN'],
#  'Huntsville-Decatur (Florence) AL': ['Monroe LA-El Dorado AR',
#   'Bluefield-Beckley-Oak Hill WV',
#   'Sioux City IA',
#   'El Paso TX',
#   'Spokane WA'],
#  'San Angelo TX': ['Eugene OR',
#   'Palm Springs CA',
#   'Lubbock TX',
#   'Lafayette LA',
#   'Bowling Green KY'],
#  'Albuquerque-Santa Fe NM': ['Memphis TN',
#   'Greensboro-High Point-Winston Salem NC',
#   'Harrisburg-Lancaster-Lebanon-York PA',
#   'Fresno-Visalia CA',
#   'Louisville KY'],
#  'Montgomery-Selma, AL': ['La Crosse-Eau Claire WI',
#   'Dothan AL',
#   'Sherman-Ada, OK',
#   'Lake Charles LA',
#   'Casper-Riverton WY'],
#  'Knoxville TN': ['Honolulu HI',
#   'Richmond-Petersburg VA',
#   'Lexington KY',
#   'Wichita-Hutchinson KS',
#   'Shreveport LA'],
#  'Chattanooga TN': ['Sioux Falls(Mitchell) SD',
#   'Johnstown-Altoona-State College PA',
#   'Wichita Falls TX & Lawton OK',
#   'South Bend-Elkhart IN',
#   'Duluth MN-Superior WI'],
#  'Reno NV': ['Lima OH',
#   'Billings, MT',
#   'Columbia SC',
#   'Abilene-Sweetwater TX',
#   'Erie PA'],
#  'Lincoln & Hastings-Kearney NE': ['Topeka KS',
#   'Ottumwa IA-Kirksville MO',
#   'Fairbanks AK',
#   'Victoria TX',
#   'Rochester NY'],
#  'El Paso TX': ['Bluefield-Beckley-Oak Hill WV',
#   'Monroe LA-El Dorado AR',
#   'Springfield-Holyoke MA',
#   'Huntsville-Decatur (Florence) AL',
#   'Sioux City IA'],
#  'Anchorage AK': ['Lansing MI',
#   'Medford-Klamath Falls OR',
#   'Syracuse NY',
#   'Florence-Myrtle Beach SC',
#   'Greenville-New Bern-Washington NC'],
#  'Albany GA': ['Odessa-Midland TX',
#   'Hattiesburg-Laurel MS',
#   'Greenville-New Bern-Washington NC',
#   'Florence-Myrtle Beach SC',
#   'Syracuse NY'],
#  'Odessa-Midland TX': ['Greenville-New Bern-Washington NC',
#   'Albany GA',
#   'Florence-Myrtle Beach SC',
#   'Syracuse NY',
#   'Medford-Klamath Falls OR'],
#  'La Crosse-Eau Claire WI': ['Montgomery-Selma, AL',
#   'Lake Charles LA',
#   'Dothan AL',
#   'Sherman-Ada, OK',
#   'Eureka CA'],
#  'Tulsa OK': ['Lexington KY',
#   'Richmond-Petersburg VA',
#   'Charleston-Huntington WV',
#   'Knoxville TN',
#   'Honolulu HI'],
#  'South Bend-Elkhart IN': ['Wichita Falls TX & Lawton OK',
#   'Duluth MN-Superior WI',
#   'Johnstown-Altoona-State College PA',
#   'Joplin MO-Pittsburg KS',
#   'Sioux Falls(Mitchell) SD'],
#  'Harrisburg-Lancaster-Lebanon-York PA': ['Greensboro-High Point-Winston Salem NC',
#   'Memphis TN',
#   'Albuquerque-Santa Fe NM',
#   'Grand Rapids-Kalamazoo-Battle Creek MI',
#   'Oklahoma City OK'],
#  'Medford-Klamath Falls OR': ['Syracuse NY',
#   'Florence-Myrtle Beach SC',
#   'Anchorage AK',
#   'Greenville-New Bern-Washington NC',
#   'Lansing MI'],
#  'Hattiesburg-Laurel MS': ['Albany GA',
#   'Odessa-Midland TX',
#   'Juneau AK',
#   'Greenville-New Bern-Washington NC',
#   'Florence-Myrtle Beach SC'],
#  'Augusta GA': ['Jackson MS',
#   'Presque Isle ME',
#   'Beaumont-Port Arthur TX',
#   'Bangor ME',
#   'Alexandria LA'],
#  'Ft. Wayne IN': ['Terre Haute IN',
#   'Columbus-Tupelo-West Point MS',
#   'Clarksburg-Weston WV',
#   'Wheeling WV-Steubenville OH',
#   'Corpus Christi TX'],
#  'Springfield MO': ['Burlington VT-Plattsburgh NY',
#   'Davenport IA-Rock Island-Moline IL',
#   'Tri-Cities TN-VA',
#   'Dayton OH',
#   'Evansville IN'],
#  'Chico-Redding CA': ['Yuma AZ-El Centro CA',
#   'Omaha NE',
#   'Utica NY',
#   'Victoria TX',
#   'Fairbanks AK'],
#  'Minot-Bismarck-Dickinson(Williston) ND': ['Eureka CA',
#   'Rapid City SD',
#   'Marquette MI',
#   'Lake Charles LA',
#   'Lansing MI'],
#  'Wichita-Hutchinson KS': ['Shreveport LA',
#   'Flint-Saginaw-Bay City MI',
#   'Toledo OH',
#   'Portland-Auburn ME',
#   'Honolulu HI'],
#  'Little Rock-Pine Bluff AR': ['Albany-Schenectady-Troy NY',
#   'Charleston-Huntington WV',
#   'Tulsa OK',
#   'Wilkes Barre-Scranton PA',
#   'Lexington KY'],
#  'Lexington KY': ['Richmond-Petersburg VA',
#   'Tulsa OK',
#   'Knoxville TN',
#   'Charleston-Huntington WV',
#   'Honolulu HI'],
#  'Bakersfield CA': ['Joplin MO-Pittsburg KS',
#   'Duluth MN-Superior WI',
#   'South Bend-Elkhart IN',
#   'Wichita Falls TX & Lawton OK',
#   'Johnstown-Altoona-State College PA'],
#  'Juneau AK': ['Hattiesburg-Laurel MS',
#   'Lafayette LA',
#   'Albany GA',
#   'Odessa-Midland TX',
#   'Greenville-New Bern-Washington NC'],
#  'Johnstown-Altoona-State College PA': ['Sioux Falls(Mitchell) SD',
#   'Chattanooga TN',
#   'Wichita Falls TX & Lawton OK',
#   'South Bend-Elkhart IN',
#   'Duluth MN-Superior WI'],
#  'Topeka KS': ['Lincoln & Hastings-Kearney NE',
#   'Ottumwa IA-Kirksville MO',
#   'Fairbanks AK',
#   'Victoria TX',
#   'Rochester NY'],
#  'Flint-Saginaw-Bay City MI': ['Shreveport LA',
#   'Wichita-Hutchinson KS',
#   'Toledo OH',
#   'Portland-Auburn ME',
#   'Champaign & Springfield-Decatur IL'],
#  'Hartford & New Haven CT': ['Indianapolis IN',
#   'Cincinnati OH',
#   'Norfolk-Portsmouth-Newport News VA',
#   'West Palm Beach-Ft. Pierce FL',
#   'Pittsburgh PA'],
#  'Sherman-Ada, OK': ['Dothan AL',
#   'Montgomery-Selma, AL',
#   'La Crosse-Eau Claire WI',
#   'Casper-Riverton WY',
#   'Lake Charles LA'],
#  'Rapid City SD': ['Minot-Bismarck-Dickinson(Williston) ND',
#   'Eureka CA',
#   'Marquette MI',
#   'Lansing MI',
#   'Lake Charles LA'],
#  'Macon GA': ['Peoria-Bloomington IL',
#   'Greenwood-Greenville MS',
#   'Chattanooga TN',
#   'Sioux Falls(Mitchell) SD',
#   'Johnstown-Altoona-State College PA'],
#  'Albany-Schenectady-Troy NY': ['Little Rock-Pine Bluff AR',
#   'Charleston-Huntington WV',
#   'Tulsa OK',
#   'Lexington KY',
#   'Richmond-Petersburg VA'],
#  'Lake Charles LA': ['La Crosse-Eau Claire WI',
#   'Montgomery-Selma, AL',
#   'Dothan AL',
#   'Eureka CA',
#   'Minot-Bismarck-Dickinson(Williston) ND'],
#  'Yuma AZ-El Centro CA': ['Chico-Redding CA',
#   'Omaha NE',
#   'Utica NY',
#   'Victoria TX',
#   'Fairbanks AK'],
#  'Marquette MI': ['Rapid City SD',
#   'Minot-Bismarck-Dickinson(Williston) ND',
#   'Eureka CA',
#   'Lansing MI',
#   'Anchorage AK'],
#  'Corpus Christi TX': ['Elmira (Corning) NY',
#   'Columbus-Tupelo-West Point MS',
#   'Terre Haute IN',
#   'Ft. Wayne IN',
#   'Bangor ME'],
#  'Dothan AL': ['Sherman-Ada, OK',
#   'Montgomery-Selma, AL',
#   'La Crosse-Eau Claire WI',
#   'Lake Charles LA',
#   'Casper-Riverton WY'],
#  'Toledo OH': ['Portland-Auburn ME',
#   'Champaign & Springfield-Decatur IL',
#   'Flint-Saginaw-Bay City MI',
#   'Shreveport LA',
#   'Wichita-Hutchinson KS'],
#  'Peoria-Bloomington IL': ['Macon GA',
#   'Greenwood-Greenville MS',
#   'Chattanooga TN',
#   'Binghamton NY',
#   'Sioux Falls(Mitchell) SD'],
#  'Fargo-Valley City ND': ['Wheeling WV-Steubenville OH',
#   'Wausau-Rhinelander WI',
#   'Clarksburg-Weston WV',
#   'Ft. Wayne IN',
#   'Meridian MS'],
#  'Sioux Falls(Mitchell) SD': ['Chattanooga TN',
#   'Johnstown-Altoona-State College PA',
#   'Wichita Falls TX & Lawton OK',
#   'South Bend-Elkhart IN',
#   'Duluth MN-Superior WI'],
#  'Eureka CA': ['Minot-Bismarck-Dickinson(Williston) ND',
#   'Rapid City SD',
#   'Marquette MI',
#   'Lake Charles LA',
#   'La Crosse-Eau Claire WI'],
#  'Indianapolis IN': ['Cincinnati OH',
#   'Hartford & New Haven CT',
#   'Norfolk-Portsmouth-Newport News VA',
#   'Pittsburgh PA',
#   'West Palm Beach-Ft. Pierce FL'],
#  'Erie PA': ['Columbia SC',
#   'Tucson (Sierra Vista) AZ',
#   'Reno NV',
#   'Watertown NY',
#   'Lima OH'],
#  'Fresno-Visalia CA': ['Louisville KY',
#   'Albuquerque-Santa Fe NM',
#   'Memphis TN',
#   'Greensboro-High Point-Winston Salem NC',
#   'Harrisburg-Lancaster-Lebanon-York PA'],
#  'Portland-Auburn ME': ['Toledo OH',
#   'Champaign & Springfield-Decatur IL',
#   'Flint-Saginaw-Bay City MI',
#   'Shreveport LA',
#   'Wichita-Hutchinson KS'],
#  'Beaumont-Port Arthur TX': ['Bangor ME',
#   'Elmira (Corning) NY',
#   'Corpus Christi TX',
#   'Augusta GA',
#   'Jackson MS'],
#  'Abilene-Sweetwater TX': ['Billings, MT',
#   'Laredo TX',
#   'Lima OH',
#   'Rochester NY',
#   'Reno NV'],
#  'Utica NY': ['Victoria TX',
#   'Fairbanks AK',
#   'Ottumwa IA-Kirksville MO',
#   'Topeka KS',
#   'Lincoln & Hastings-Kearney NE'],
#  'Columbus-Tupelo-West Point MS': ['Terre Haute IN',
#   'Ft. Wayne IN',
#   'Corpus Christi TX',
#   'Elmira (Corning) NY',
#   'Clarksburg-Weston WV'],
#  'Youngstown OH': ['Spokane WA',
#   'Sioux City IA',
#   'Bakersfield CA',
#   'Huntsville-Decatur (Florence) AL',
#   'Monroe LA-El Dorado AR'],
#  'Billings, MT': ['Abilene-Sweetwater TX',
#   'Lima OH',
#   'Laredo TX',
#   'Rochester NY',
#   'Reno NV'],
#  'Burlington VT-Plattsburgh NY': ['Springfield MO',
#   'Davenport IA-Rock Island-Moline IL',
#   'Tri-Cities TN-VA',
#   'Dayton OH',
#   'Evansville IN'],
#  'Laredo TX': ['Abilene-Sweetwater TX',
#   'Billings, MT',
#   'Rochester NY',
#   'Lima OH',
#   'Lincoln & Hastings-Kearney NE'],
#  'Casper-Riverton WY': ['Omaha NE',
#   'Sherman-Ada, OK',
#   'Dothan AL',
#   'Montgomery-Selma, AL',
#   'Chico-Redding CA'],
#  'Champaign & Springfield-Decatur IL': ['Portland-Auburn ME',
#   'Toledo OH',
#   'Davenport IA-Rock Island-Moline IL',
#   'Burlington VT-Plattsburgh NY',
#   'Springfield MO'],
#  'Springfield-Holyoke MA': ['El Paso TX',
#   'Bluefield-Beckley-Oak Hill WV',
#   'Monroe LA-El Dorado AR',
#   'Huntsville-Decatur (Florence) AL',
#   'Sioux City IA'],
#  'Evansville IN': ['Des Moines-Ames IA',
#   'Springfield-Holyoke MA',
#   'El Paso TX',
#   'Dayton OH',
#   'Bluefield-Beckley-Oak Hill WV'],
#  'Wausau-Rhinelander WI': ['Fargo-Valley City ND',
#   'Meridian MS',
#   'Wheeling WV-Steubenville OH',
#   'Butte-Bozeman MT',
#   'Clarksburg-Weston WV'],
#  'Tri-Cities TN-VA': ['Dayton OH',
#   'Springfield MO',
#   'Burlington VT-Plattsburgh NY',
#   'Davenport IA-Rock Island-Moline IL',
#   'Evansville IN'],
#  'Watertown NY': ['Alexandria LA',
#   'Tucson (Sierra Vista) AZ',
#   'Erie PA',
#   'Columbia SC',
#   'Reno NV'],
#  'Lima OH': ['Billings, MT',
#   'Abilene-Sweetwater TX',
#   'Laredo TX',
#   'Reno NV',
#   'Rochester NY'],
#  'Bangor ME': ['Beaumont-Port Arthur TX',
#   'Elmira (Corning) NY',
#   'Corpus Christi TX',
#   'Augusta GA',
#   'Jackson MS'],
#  'Terre Haute IN': ['Columbus-Tupelo-West Point MS',
#   'Ft. Wayne IN',
#   'Corpus Christi TX',
#   'Clarksburg-Weston WV',
#   'Elmira (Corning) NY'],
#  'Alexandria LA': ['Watertown NY',
#   'Tucson (Sierra Vista) AZ',
#   'Erie PA',
#   'Columbia SC',
#   'Presque Isle ME'],
#  'Fairbanks AK': ['Victoria TX',
#   'Ottumwa IA-Kirksville MO',
#   'Topeka KS',
#   'Lincoln & Hastings-Kearney NE',
#   'Utica NY'],
#  'Ottumwa IA-Kirksville MO': ['Topeka KS',
#   'Lincoln & Hastings-Kearney NE',
#   'Fairbanks AK',
#   'Victoria TX',
#   'Utica NY'],
#  'Victoria TX': ['Fairbanks AK',
#   'Ottumwa IA-Kirksville MO',
#   'Topeka KS',
#   'Lincoln & Hastings-Kearney NE',
#   'Utica NY'],
#  'Shreveport LA': ['Wichita-Hutchinson KS',
#   'Flint-Saginaw-Bay City MI',
#   'Toledo OH',
#   'Portland-Auburn ME',
#   'Honolulu HI'],
#  'Wilkes Barre-Scranton PA': ['Buffalo NY',
#   'Little Rock-Pine Bluff AR',
#   'Albany-Schenectady-Troy NY',
#   'Charleston-Huntington WV',
#   'Tulsa OK'],
#  'Wheeling WV-Steubenville OH': ['Clarksburg-Weston WV',
#   'Fargo-Valley City ND',
#   'Ft. Wayne IN',
#   'Terre Haute IN',
#   'Wausau-Rhinelander WI'],
#  'Wichita Falls TX & Lawton OK': ['South Bend-Elkhart IN',
#   'Duluth MN-Superior WI',
#   'Johnstown-Altoona-State College PA',
#   'Sioux Falls(Mitchell) SD',
#   'Joplin MO-Pittsburg KS'],
#  'Davenport IA-Rock Island-Moline IL': ['Burlington VT-Plattsburgh NY',
#   'Springfield MO',
#   'Tri-Cities TN-VA',
#   'Dayton OH',
#   'Evansville IN'],
#  'Elmira (Corning) NY': ['Corpus Christi TX',
#   'Columbus-Tupelo-West Point MS',
#   'Bangor ME',
#   'Beaumont-Port Arthur TX',
#   'Terre Haute IN'],
#  'Binghamton NY': ['Butte-Bozeman MT',
#   'Meridian MS',
#   'Wausau-Rhinelander WI',
#   'Peoria-Bloomington IL',
#   'Macon GA'],
#  'Duluth MN-Superior WI': ['Joplin MO-Pittsburg KS',
#   'South Bend-Elkhart IN',
#   'Wichita Falls TX & Lawton OK',
#   'Johnstown-Altoona-State College PA',
#   'Sioux Falls(Mitchell) SD'],
#  'Clarksburg-Weston WV': ['Wheeling WV-Steubenville OH',
#   'Ft. Wayne IN',
#   'Fargo-Valley City ND',
#   'Terre Haute IN',
#   'Columbus-Tupelo-West Point MS'],
#  'Joplin MO-Pittsburg KS': ['Duluth MN-Superior WI',
#   'South Bend-Elkhart IN',
#   'Wichita Falls TX & Lawton OK',
#   'Johnstown-Altoona-State College PA',
#   'Sioux Falls(Mitchell) SD'],
#  'Monroe LA-El Dorado AR': ['Bluefield-Beckley-Oak Hill WV',
#   'El Paso TX',
#   'Huntsville-Decatur (Florence) AL',
#   'Springfield-Holyoke MA',
#   'Sioux City IA'],
#  'Presque Isle ME': ['Jackson MS',
#   'Augusta GA',
#   'Beaumont-Port Arthur TX',
#   'Bangor ME',
#   'Alexandria LA'],
#  'Meridian MS': ['Butte-Bozeman MT',
#   'Binghamton NY',
#   'Wausau-Rhinelander WI',
#   'Fargo-Valley City ND',
#   'Wheeling WV-Steubenville OH'],
#  'Sioux City IA': ['Spokane WA',
#   'Huntsville-Decatur (Florence) AL',
#   'Monroe LA-El Dorado AR',
#   'Bluefield-Beckley-Oak Hill WV',
#   'El Paso TX'],
#  'Butte-Bozeman MT': ['Binghamton NY',
#   'Meridian MS',
#   'Wausau-Rhinelander WI',
#   'Fargo-Valley City ND',
#   'Peoria-Bloomington IL'],
#  'Greenwood-Greenville MS': ['Macon GA',
#   'Peoria-Bloomington IL',
#   'Chattanooga TN',
#   'Sioux Falls(Mitchell) SD',
#   'Johnstown-Altoona-State College PA'],
#  'Charleston-Huntington WV': ['Tulsa OK',
#   'Lexington KY',
#   'Richmond-Petersburg VA',
#   'Albany-Schenectady-Troy NY',
#   'Knoxville TN'],
#  'Bluefield-Beckley-Oak Hill WV': ['Monroe LA-El Dorado AR',
#   'El Paso TX',
#   'Huntsville-Decatur (Florence) AL',
#   'Springfield-Holyoke MA',
#   'Sioux City IA']}
